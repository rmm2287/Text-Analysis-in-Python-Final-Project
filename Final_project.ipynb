# %% [markdown]
# <a href="https://colab.research.google.com/github/rmm2287/Text-Analysis-in-Python-Final-Project/blob/main/Final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Undertsanding 311 Inquiries in New York
# New York City's 311 system began in 2003 as a way for New Yorkers to communicate complaints or receive other information about city services. In the over 20 years that the system has been active, 525 contacts (unique callers) have utilized the system.
#
# For my project, I wanted to investigate the most common kind of calls that 311 gets from New Yorkers. Utilizing New York City's Open Data platform, I was able to pull data between March and May of 2024. I selected this time period because I wanted to avoid a time period in which there is significant extreme weather (warm or cold). I wanted to exclude these conditions as I anticipated that most calls would be in regards to weather specific challenges. While this is a citywide system, data shows that most people who utilize the system are older adults, most often women. These individuals are also likely higher income earners. Even with this in mind, 311 is the primary point of reference for what issues are most experienced by New Yorkers, so it remains the most valuable source of information even if its primarily being utilized by specific demographics.
#
# With this research question in mind, to better understand what New Yorkers are asking about or reporting, I determined my hypothesis for this project was that most data would relate to personal issues (rather than reporting public issues) and that those issues would lilely be negative in sentiment. It is well-known that people are more likely to communicate in instances of being upset, so this seemed like a likely conclusion.
#
# This project is relevant to policy makers as it can increase awareness of the issues most important to New Yorkers. This could influence how policymakers spend funds, areas where additional staffing or resources might be needed, or generally to make policy makers more aware of resident’s priorities. This could be beneficial long term as policymakers would be able to more effectively make policy for the city.
#
# # Method
#
# When evaluating the 311 Call Center Inquiry data, it represents fairly basic call center information. The data collects the date and time of the calls, the agency most associated with the call, an inquiry name, a brief description, and the resolution of the call. For my project, I was able to utilize the date/time category to narrow down to the March to May time period I had decided on. Other than that initial search, only the inquiry name and the brief description were relevant to my research.
#
# The first major challenge I experienced is that the New York Open Data platform will only allow for 1000 rows to be exported at a time. I was able to utilize ChatGPT to navigate this issue, and had to utilize that code over and over again to ensure the correct data was being analyzed throughout my data.
#
# I performed the following methodology and analysis on the dataset. I wrote and ran the python script in a GoogleCollab notebook. Besides built-in python features, I used libraries including pandas, WordCloud, nltk, mathplotlib, textblob, VADER, and tomotopy. The methodology consisted of text processing and keyword analysis and theme categorization and sentiment analysis.
#
# Within the text processing and keyword analysis I removed common stop words. I also added a list of other stopwords to exclude from the data set. These words included new, york, New York, complaint, repair, report, service, requested, needed, and issue. These were words that occurred often in the data set, and words in which the meaning and presence in the results were not generating any value to understanding the dataset. The test in the dataset was tokenized using the NLTK library which split the individual texts into words or tokes. In addition, all text was converted to lowercase and non-alphabetical characters like numbers were removed. Missing or incomplete entries were also removed from the inquiry name and brief description columns. The reprocessed data was then stores in processed_inquiry_name and processed_description, both representing data from the previously mentioned relevant columns of data.
#
# Using this newly processed data, a WordCloud was created to show some of the most used words throughout the dataset. Some of the largest (and therefore, most common) terms in the WordCloud included camera violation, payment dispute, maintenance problem, and parking ticket. Then, the top twenty keywords were then pulled from the dataset along with their frequency of use.
#
# To better understand the themes in the dataset, tomotopy was used which specified five topics for analysis based on the content within the dataset. Each document was represented as a sequence of words with the combination of inquiry name and brief description for each record being used as the input text. This data was then fed into the model and processed. The top words for each topic were extracted which allowed for and interpretation of the content. These top words provided insight into the key themes and issues prevalent in the dataset, which were essential for understanding the nature of the proposed research question. The topic assignments were then utilized to categorize the other terms in the dataset. This assignment process helped to structure the dataset into distinct thematic groups based on the content of the inquiries and descriptions.
#
# Lastly, sentiment analysis was conducted to determine the emotional tone of the text. Using TextBlob and VADER, the polarity score of the text was calculated. A polarity score greater than 0 indicates a positive sentiment, less than 0 indicates a negative sentiment, and a score of signifies neutrality. For each word, the polarity was computed and classified. VADER in particular is often used for social media, but in this case, I chose to use it as it can be valuable in cases of service requests. VADER assigns compound scores which range from -1 (most negative) to 1 (most positive). Both sentiment analysis results were compared to provide a more comprehensive understanding of the emotional tone of the call center data inquiries.
#
# # Results
# Upon finding the code to pull the appropriate data for March to May 2024, I found myself with 1,075,365 rows of data to analyze. While this is a significant amount of data, my analysis made it possible to better understand what is conveyed in the over one million lines of data.
# The below WordCloud shows the most commone words and phrases to exist in the data. This WordCloud excludes stopwords to the best of my ability.
# ![image.png](data:image/png;base64,...)
#
# When evaluating the frequency, I gathered the top 20 terms in the data and their corresponding frequencies. I had challenges removing some stopwords from this analysis, so the graphs show some words that I otherwise might have removed.
# ![image.png](data:image/png;base64,...)
# The TF-IDF data also produced a graph with some words and phrases and their accompanying TF-IDF scores.
# Lastly, the sentiment analysis is conveyed in the below graph with shows both tools I used to conduct the analysis grouped by positive, negative, or neutral. While I pulled sentiment analysis for individual lines of data, this graph better conveyed the overall trend within the dataset.
# ![image.png](data:image/png;base64,...)
#
# By leveraging advanced natural language processing methods, including sentiment analysis, frequency analysis, and TF-IDF vectorization, the raw textual data was transformed into actionable intelligence about New York City's service requests. The multi-method approach not only revealed the most prevalent issues and concerns but also provided nuanced insights into the emotional landscape of urban service interactions. The sentiment analysis, in particular, highlighted the diverse range of experiences and perspectives embedded within these requests, offering a unique window into the city's operational challenges and citizen experiences. While the analysis presented here provides valuable initial insights, it also opens the door to further investigation, suggesting the potential for more targeted research and data-driven policy recommendations. Future work could explore deeper contextual analysis and more granular sentiment categorizations to continue enhancing policy makers understanding of New York service concerns.
#
# # Discussion & Conclusion
# The text processing, topic modeling, and sentiment analysis conducted throughout this project are beneficial for better understanding the kinds of complaints and questions most often raised by New Yorkers. In summary, this research effectively demonstrates the analysis of 311 Call Center Inquiry Open Data. Based on the data, there are a variety of issues experienced by New Yorkers, including parking violations and issues with water and pipes. Additionally, the sentiment analysis shows that most calls are negative rather than positive or neutral. This confirms my hypothesis that a majority of calls would be negative and would focus on issues of a personal nature rather than on reporting public issues.
#
# The ability to process and visualize common themes and sentiments provides a powerful tool for understanding trends in public service requests. This analysis aligns with findings from other studies of NYC 311 data, which have also identified noise complaints, residential issues, and parking problems as frequent concerns. The high volume of requests, with millions annually, underscores the importance of efficient data analysis to improve city services.
#
# Furthermore, while it is know that the data might skew towards specific demographics, this research contributes to the broader field of urban analytics by demonstrating how 311 data can serve as a unique indicator of local urban function, condition, and service level. The analysis of complaint types and their distribution across different city areas can reveal patterns in urban issues and help prioritize resource allocation.
#
# Future exploration of this data could increase insights into weathers impact on complaints. It could also track how priority items change year after year, providing additional insight into resident concerns and resource allocation into the future.
#
# By continuing to refine these analytical techniques, city officials and researchers can gain deeper insights into the needs and concerns of New Yorkers, ultimately leading to more responsive and efficient urban governance.
#
# # Key Learnings and What I Would Change in the Future
# If I were to do this project again, I would have spent more time putting all the relevant data into a CSV file. I attempted this during the project and had issues because of the code to pull more than 1000 rows from the data. However, not saving the data in a CSV meant re-running the code each time I wanted to do something, which was time consuming and hard on the GoogleCollab system. I also had challenges removing stopwords, as I had to do that within each section of code as well. In the future, I would spend more time to understand how to do this from the beginning. Overall, I found this to be an imperfect, but valuable first attempt at conducting text analysis, and I look forward to future opportunities to work with these tools.

# %% [markdown]
# # Full Code

# %%
import requests
import pandas as pd
from io import StringIO

url = 'https://data.cityofnewyork.us/resource/wewp-mm3p.csv'

limit = 1000
offset = 0

all_data = []

start_date = '2024-03-01'
end_date = '2024-05-31'

while True:
    params = {
        '$limit': limit,
        '$offset': offset,
        '$where': f"date >= '{start_date}' AND date <= '{end_date}'"
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        chunk_data = pd.read_csv(StringIO(response.text))

        all_data.append(chunk_data)

        if len(chunk_data) < limit:
            print(f"Fetched {len(chunk_data)} rows, stopping pagination.")
            break

        offset += limit
        print(f"Fetched {len(chunk_data)} rows, moving to offset {offset}.")
    else:
        print(f"Error {response.status_code}: Unable to fetch data.")
        break

final_data = pd.concat(all_data, ignore_index=True)

print(f"Total rows fetched within date range: {len(final_data)}")
print(final_data.head())
# Out:
# Fetched 1000 rows, moving to offset 1000.
# Fetched 1000 rows, moving to offset 2000.
# Fetched 1000 rows, moving to offset 3000.
# Fetched 1000 rows, moving to offset 4000.
# Fetched 1000 rows, moving to offset 5000.
# Fetched 1000 rows, moving to offset 6000.
# Fetched 1000 rows, moving to offset 7000.
# Fetched 1000 rows, moving to offset 8000.
# Fetched 1000 rows, moving to offset 9000.
# Fetched 1000 rows, moving to offset 10000.
# Fetched 1000 rows, moving to offset 11000.
# Fetched 1000 rows, moving to offset 12000.
# Fetched 1000 rows, moving to offset 13000.
# Fetched 1000 rows, moving to offset 14000.
# Fetched 1000 rows, moving to offset 15000.
# Fetched 1000 rows, moving to offset 16000.
# Fetched 1000 rows, moving to offset 17000.
# Fetched 1000 rows, moving to offset 18000.
# Fetched 1000 rows, moving to offset 19000.
# Fetched 1000 rows, moving to offset 20000.
# Fetched 1000 rows, moving to offset 21000.
# Fetched 1000 rows, moving to offset 22000.
# ...

# %%
print("Columns in the dataset:")
print(final_data.columns)
# Out:
# Columns in the dataset:
# Index(['unique_id', 'date', 'time', 'date_time', 'agency', 'agency_name',
#        'inquiry_name', 'brief_description', 'call_resolution'],
#       dtype='object')

# %%
print("\nFirst few rows of the dataset:")
print(final_data.head())
# Out:
# First few rows of the dataset:
#    unique_id                     date        time                date_time  \
# 0  158187047  2024-03-01T00:00:00.000  1:17:01 AM  2024-03-01T01:17:01.000
# 1  158187048  2024-03-01T00:00:00.000  1:13:21 AM  2024-03-01T01:13:21.000
# 2  158187117  2024-03-01T00:00:00.000  1:56:02 AM  2024-03-01T01:56:02.000
# 3  158187118  2024-03-01T00:00:00.000  1:58:48 AM  2024-03-01T01:58:48.000
# 4  158187119  2024-03-01T00:00:00.000  1:56:14 AM  2024-03-01T01:56:14.000
#
#    agency  agency_name                    inquiry_name  \
# 0     NaN          NaN                 Stolen Property
# 1     NaN          NaN       988 Mental Health Support
# 2     NaN          NaN              Bulk Item Disposal
# 3     NaN          NaN                   Date and Time
# 4     NaN          NaN  City Agency or Worker Feedback
#
#                                    brief_description  call_resolution
# 0                Call 911 to report stolen property.              NaN
# ...

# %%
print("\nNumber of rows and columns in the dataset:")
print(final_data.shape)
# Out:
# Number of rows and columns in the dataset:
# (1075365, 9)

# %%
required_columns = ['inquiry_name', 'brief_description']

# %%
cleaned_data = final_data[['inquiry_name', 'brief_description']]

# %%
print("\nCleaned Data (only inquiry_name and brief_description):")
print(cleaned_data.head())
# Out:
# Cleaned Data (only inquiry_name and brief_description):
#                           inquiry_name  \
# 0                  Noise from Neighbor
# 1                  Noise from Neighbor
# 2  Noise from Bar, Club, or Restaurant
# 3                       Smoke or Fumes
# 4                    Homeless Shelters
#
#                                    brief_description
# 0                           Report a noisy neighbor.
# 1                           Report a noisy neighbor.
# 2  Report noise, including music, coming from a b...
# 3                 Call 911 to report smoke or fumes.
# 4                 Apply for homeless shelter intake.

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

import nltk
nltk.download('stopwords', quiet=True)

cleaned_data = final_data[['brief_description']].copy()

def preprocess_text(text):
    if isinstance(text, str) and text.strip():
        tokens = re.findall(r'\b\w+\b', text.lower())
        stop_words = set(stopwords.words('english'))
        additional_stopwords = {'new', 'york', 'report', 'complaint', 'repair', 'service', 'requested', 'needed', 'issue'}
        stop_words.update(additional_stopwords)
        filtered_tokens = [word for word in tokens if word not in stop_words]
        return ' '.join(filtered_tokens)
    else:
        return ''

cleaned_data['cleaned_description'] = cleaned_data['brief_description'].apply(preprocess_text)

vectorizer = TfidfVectorizer(max_features=10)
X = vectorizer.fit_transform(cleaned_data['cleaned_description'])

feature_names = vectorizer.get_feature_names_out()
print("Top 10 features:", feature_names)
# Out:
# Top 10 features: ['building' 'city' 'get' 'information' 'learn' 'parking' 'problem'
#  'property' 'public' 'vehicle']

# %%
import requests
import pandas as pd
from io import StringIO
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')

url = 'https://data.cityofnewyork.us/resource/wewp-mm3p.csv'

limit = 1000
offset = 0

all_data = []
start_date = '2024-03-01'
end_date = '2024-05-31'

stop_words = set(stopwords.words('english'))
additional_stopwords = {'new york', 'new', 'york', 'report', 'complaint', 'repair', 'service', 'requested', 'needed', 'issue', 'get'}
stop_words.update(additional_stopwords)

def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    return [word for word in tokens if word.isalpha() and word not in stop_words]

while True:
    params = {
        '$limit': limit,
        '$offset': offset,
        '$where': f"date >= '{start_date}' AND date <= '{end_date}'"
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        chunk_data = pd.read_csv(StringIO(response.text))
        all_data.append(chunk_data)

        if len(chunk_data) < limit:
            print(f"Fetched {len(chunk_data)} rows, stopping pagination.")
            break

        offset += limit
        print(f"Fetched {len(chunk_data)} rows, moving to offset {offset}.")
    else:
        print(f"Error {response.status_code}: Unable to fetch data.")
        break

final_data = pd.concat(all_data, ignore_index=True)

final_data['processed_description'] = final_data['brief_description'].apply(lambda x: preprocess_text(str(x)))

all_words = [word for desc in final_data['processed_description'] for word in desc]

word_counts = Counter(all_words)

top_20_words = word_counts.most_common(20)

top_20_df = pd.DataFrame(top_20_words, columns=['Word', 'Frequency'])
print(top_20_df)

plt.figure(figsize=(12, 8))
plt.barh(top_20_df['Word'], top_20_df['Frequency'], color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.title('Top 20 Most Frequent Words')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Fetched 1000 rows, moving to offset 1000.
# Fetched 1000 rows, moving to offset 2000.
# Fetched 1000 rows, moving to offset 3000.
# Fetched 1000 rows, moving to offset 4000.
# Fetched 1000 rows, moving to offset 5000.
# Fetched 1000 rows, moving to offset 6000.
# Fetched 1000 rows, moving to offset 7000.
# Fetched 1000 rows, moving to offset 8000.
# Fetched 1000 rows, moving to offset 9000.
# Fetched 1000 rows, moving to offset 10000.
# Fetched 1000 rows, moving to offset 11000.
# Fetched 1000 rows, moving to offset 12000.
# Fetched 1000 rows, moving to offset 13000.
# Fetched 1000 rows, moving to offset 14000.
# Fetched 1000 rows, moving to offset 15000.
# Fetched 1000 rows, moving to offset 16000.
# Fetched 1000 rows, moving to offset 17000.
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

nltk.download('stopwords')

additional_stopwords = ['new york', 'new', 'york', 'report', 'complaint', 'repair', 'service', 'requested', 'needed', 'issue']

stop_words = set(stopwords.words('english')) | set(additional_stopwords)

data = {
    'brief_description': [
        'Pipe repair requested in New York.',
        'Water service complaint in York region.',
        'Complaint about new water pipe installation.',
        'Repair needed for broken pipe.',
        'Service issue with water pipe in New York.'
    ]
}

cleaned_data = pd.DataFrame(data)

def remove_stopwords(text):
    tokens = text.lower().split()

    return ' '.join([word for word in tokens if word not in stop_words])

cleaned_data['cleaned_description'] = cleaned_data['brief_description'].apply(remove_stopwords)

vectorizer = TfidfVectorizer(max_features=20)

X_matrix = vectorizer.fit_transform(cleaned_data['cleaned_description'])

terms = vectorizer.get_feature_names_out()

sum_tfidf = X_matrix.sum(axis=0).A1

term_scores = pd.DataFrame(zip(terms, sum_tfidf), columns=['Term', 'TF-IDF Score'])

top_20_terms = term_scores.sort_values(by='TF-IDF Score', ascending=False).head(20)

top_20_terms = top_20_terms[top_20_terms['Term'] != 'york']

print("\nTop 20 Terms based on TF-IDF (excluding 'york'):")
print(top_20_terms)

plt.figure(figsize=(12, 8))
plt.barh(top_20_terms['Term'], top_20_terms['TF-IDF Score'], color='skyblue')
plt.xlabel('TF-IDF Score')
plt.ylabel('Terms')
plt.title('Top Terms based on TF-IDF Scores (Excluding "york")')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Top 20 Terms based on TF-IDF (excluding 'york'):
#            Term  TF-IDF Score
# 2          pipe      1.960633
# 4         water      1.623057
# 0        broken      0.871247
# 3        region      0.830881
# 1  installation      0.752515

# %%
import nltk
import requests
import pandas as pd
from io import StringIO
import re
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    nltk.download('stopwords')

additional_stopwords = {'new york', 'new', 'york', 'report', 'complaint', 'repair', 'service', 'requested', 'needed', 'issue', 'get'}
stop_words = set(stopwords.words('english')) | set(additional_stopwords)

def simple_tokenize(text):
    return re.findall(r'\b\w+\b', text.lower())

url = 'https://data.cityofnewyork.us/resource/wewp-mm3p.csv'

limit = 1000
offset = 0
all_data = []

start_date = '2024-03-01'
end_date = '2024-05-31'

def preprocess_text(text):
    if isinstance(text, str):
        tokens = simple_tokenize(text)
        return [word for word in tokens if word not in stop_words]
    return []

while True:
    params = {
        '$limit': limit,
        '$offset': offset,
        '$where': f"date >= '{start_date}' AND date <= '{end_date}'"
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        chunk_data = pd.read_csv(StringIO(response.text))
        all_data.append(chunk_data)

        if len(chunk_data) < limit:
            print(f"Fetched {len(chunk_data)} rows, stopping pagination.")
            break

        offset += limit
        print(f"Fetched {len(chunk_data)} rows, moving to offset {offset}.")
    else:
        print(f"Error {response.status_code}: Unable to fetch data.")
        break

final_data = pd.concat(all_data, ignore_index=True)

print(f"Total rows fetched within date range: {len(final_data)}")
print(final_data.head())

final_data['processed_description'] = final_data['brief_description'].apply(lambda x: preprocess_text(str(x)))

corpus = ' '.join(final_data['processed_description'].apply(lambda x: ' '.join(x)))

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(corpus)

plt.figure(figsize=(10, 6))
plt.title('Most Common Terms March - May 2024', fontsize=16)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Fetched 1000 rows, moving to offset 1000.
# Fetched 1000 rows, moving to offset 2000.
# Fetched 1000 rows, moving to offset 3000.
# Fetched 1000 rows, moving to offset 4000.
# Fetched 1000 rows, moving to offset 5000.
# Fetched 1000 rows, moving to offset 6000.
# Fetched 1000 rows, moving to offset 7000.
# Fetched 1000 rows, moving to offset 8000.
# Fetched 1000 rows, moving to offset 9000.
# Fetched 1000 rows, moving to offset 10000.
# Fetched 1000 rows, moving to offset 11000.
# Fetched 1000 rows, moving to offset 12000.
# Fetched 1000 rows, moving to offset 13000.
# Fetched 1000 rows, moving to offset 14000.
# Fetched 1000 rows, moving to offset 15000.
# Fetched 1000 rows, moving to offset 16000.
# Fetched 1000 rows, moving to offset 17000.
# Fetched 1000 rows, moving to offset 18000.
# Fetched 1000 rows, moving to offset 19000.
# Fetched 1000 rows, moving to offset 20000.
# Fetched 1000 rows, moving to offset 21000.
# Fetched 1000 rows, moving to offset 22000.
# ...

# %%
pip install tomotopy

# %%
# !pip install seaborn

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import requests
import pandas as pd
from io import StringIO
import tomotopy as tp
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')

url = 'https://data.cityofnewyork.us/resource/wewp-mm3p.csv'

limit = 1000
offset = 0

all_data = []

start_date = '2024-03-01'
end_date = '2024-05-31'

while True:
    params = {
        '$limit': limit,
        '$offset': offset,
        '$where': f"date >= '{start_date}' AND date <= '{end_date}'"
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        chunk_data = pd.read_csv(StringIO(response.text))
        all_data.append(chunk_data)

        if len(chunk_data) < limit:
            print(f"Fetched {len(chunk_data)} rows, stopping pagination.")
            break

        offset += limit
        print(f"Fetched {len(chunk_data)} rows, moving to offset {offset}.")
    else:
        print(f"Error {response.status_code}: Unable to fetch data.")
        break

final_data = pd.concat(all_data, ignore_index=True)

print(f"Total rows fetched within date range: {len(final_data)}")
print(final_data.head())

stop_words = set(stopwords.words('english'))
additional_stopwords = {'new york', 'new', 'york', 'report', 'complaint', 'repair', 'service', 'requested', 'needed', 'issue'}
stop_words.update(additional_stopwords)

def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    return [word for word in tokens if word.isalpha() and word not in stop_words]

if 'inquiry_name' in final_data.columns:
    final_data['processed_inquiry_name'] = final_data['inquiry_name'].apply(lambda x: preprocess_text(str(x)))
else:
    final_data['processed_inquiry_name'] = []

if 'brief_description' in final_data.columns:
    final_data['processed_description'] = final_data['brief_description'].apply(lambda x: preprocess_text(str(x)))
else:
    final_data['processed_description'] = []

documents = final_data['processed_inquiry_name'].astype(str) + " " + final_data['processed_description'].astype(str)

model = tp.LDAModel(k=5)

for doc in documents:
    model.add_doc(doc.split())

model.train(1000)


print("\nTop words for each topic:")
for topic_id in range(model.k):
    print(f"\nTopic {topic_id + 1}:")
    words = model.get_topic_words(topic_id, top_n=10)
    for word, prob in words:
        print(f"{word}: {prob:.4f}")

print("\nTopic assignments for each document:")
for i, doc in enumerate(model.docs):
    topic_id = doc.topic
    print(f"Document {i + 1}: Topic {topic_id}")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Fetched 1000 rows, moving to offset 1000.
# Fetched 1000 rows, moving to offset 2000.
# Fetched 1000 rows, moving to offset 3000.
# Fetched 1000 rows, moving to offset 4000.
# Fetched 1000 rows, moving to offset 5000.
# Fetched 1000 rows, moving to offset 6000.
# Fetched 1000 rows, moving to offset 7000.
# Fetched 1000 rows, moving to offset 8000.
# Fetched 1000 rows, moving to offset 9000.
# Fetched 1000 rows, moving to offset 10000.
# Fetched 1000 rows, moving to offset 11000.
# Fetched 1000 rows, moving to offset 12000.
# Fetched 1000 rows, moving to offset 13000.
# Fetched 1000 rows, moving to offset 14000.
# Fetched 1000 rows, moving to offset 15000.
# Fetched 1000 rows, moving to offset 16000.
# Fetched 1000 rows, moving to offset 17000.
# ...

# %%
# !pip install -- update nltk

# %%
import requests
import pandas as pd
from io import StringIO
from textblob import TextBlob
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')

url = 'https://data.cityofnewyork.us/resource/wewp-mm3p.csv'

limit = 1000
offset = 0

all_data = []

start_date = '2024-03-01'
end_date = '2024-05-31'

while True:
    params = {
        '$limit': limit,
        '$offset': offset,
        '$where': f"date >= '{start_date}' AND date <= '{end_date}'"
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        chunk_data = pd.read_csv(StringIO(response.text))

        all_data.append(chunk_data)

        if len(chunk_data) < limit:
            print(f"Fetched {len(chunk_data)} rows, stopping pagination.")
            break

        offset += limit
        print(f"Fetched {len(chunk_data)} rows, moving to offset {offset}.")
    else:
        print(f"Error {response.status_code}: Unable to fetch data.")
        break
final_data = pd.concat(all_data, ignore_index=True)

print(f"Total rows fetched within date range: {len(final_data)}")
print(final_data.head(50))

def analyze_sentiment_textblob(text):
    blob = TextBlob(text)
    sentiment_score = blob.sentiment.polarity
    if sentiment_score > 0:
        sentiment = 'Positive'
    elif sentiment_score < 0:
        sentiment = 'Negative'
    else:
        sentiment = 'Neutral'
    return sentiment, sentiment_score

final_data['textblob_sentiment'], final_data['textblob_sentiment_score'] = zip(*final_data['brief_description'].apply(lambda x: analyze_sentiment_textblob(str(x))))

sia = SentimentIntensityAnalyzer()

def analyze_sentiment_vader(text):
    sentiment_score = sia.polarity_scores(text)
    compound_score = sentiment_score['compound']
    if compound_score > 0:
        sentiment = 'Positive'
    elif compound_score < 0:
        sentiment = 'Negative'
    else:
        sentiment = 'Neutral'
    return sentiment, compound_score

final_data['vader_sentiment'], final_data['vader_sentiment_score'] = zip(*final_data['brief_description'].apply(lambda x: analyze_sentiment_vader(str(x))))

print("\nSentiment Analysis Results:")
print(final_data[['brief_description', 'textblob_sentiment', 'textblob_sentiment_score', 'vader_sentiment', 'vader_sentiment_score']].head(50))
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Fetched 1000 rows, moving to offset 1000.
# Fetched 1000 rows, moving to offset 2000.
# Fetched 1000 rows, moving to offset 3000.
# Fetched 1000 rows, moving to offset 4000.
# Fetched 1000 rows, moving to offset 5000.
# Fetched 1000 rows, moving to offset 6000.
# Fetched 1000 rows, moving to offset 7000.
# Fetched 1000 rows, moving to offset 8000.
# Fetched 1000 rows, moving to offset 9000.
# Fetched 1000 rows, moving to offset 10000.
# Fetched 1000 rows, moving to offset 11000.
# Fetched 1000 rows, moving to offset 12000.
# Fetched 1000 rows, moving to offset 13000.
# Fetched 1000 rows, moving to offset 14000.
# Fetched 1000 rows, moving to offset 15000.
# Fetched 1000 rows, moving to offset 16000.
# Fetched 1000 rows, moving to offset 17000.
# Fetched 1000 rows, moving to offset 18000.
# Fetched 1000 rows, moving to offset 19000.
# ...

# %%
import matplotlib.pyplot as plt

textblob_counts = final_data['textblob_sentiment'].value_counts()
vader_counts = final_data['vader_sentiment'].value_counts()

fig, ax = plt.subplots(figsize=(10, 6))

width = 0.35
x = range(len(textblob_counts))

ax.bar([i - width/2 for i in x], textblob_counts.values, width, label='TextBlob', color='skyblue')
ax.bar([i + width/2 for i in x], vader_counts.values, width, label='VADER', color='lightgreen')

ax.set_ylabel('Count')
ax.set_title('Sentiment Analysis: TextBlob vs VADER')
ax.set_xticks(x)
ax.set_xticklabels(textblob_counts.index)
ax.legend()

for i, v in enumerate(textblob_counts.values):
    ax.text(i - width/2, v, str(v), ha='center', va='bottom')
for i, v in enumerate(vader_counts.values):
    ax.text(i + width/2, v, str(v), ha='center', va='bottom')

plt.tight_layout()
plt.show()
